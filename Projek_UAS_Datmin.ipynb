# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminnshw/datmin/blob/main/Projek_UAS_Datmin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projek UAS Data Mining

# %% [markdown]
# Anggota
# 1. Audrey Aliyya Marlavi
# 2. Yasmin Nashwa

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Library Preparation

# %%
#import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msnum
from scipy.stats import skew

# %% [markdown]
# ## Load Data

# %%
# !gdown 1XRQnGAYhyMH-B1lDIRsbI064EyE52mBd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XRQnGAYhyMH-B1lDIRsbI064EyE52mBd
# To: /content/datmin.xlsx
# 100% 110M/110M [00:02<00:00, 38.9MB/s]

# %%
df = pd.read_excel('/content/datmin.xlsx')
df
# Out:
#             ID WILAYAH JENIS KELAMIN  USIA  LAMA BERDINAS PENDIDIKAN TERAKHIR  \
# 0            1  KALBAR   LAKI - LAKI  34.0           16.0                 SMA
# 1            2  KALBAR   LAKI - LAKI  43.0           23.0                 SMA
# 2            3  KALBAR   LAKI - LAKI  21.0            1.0                 SMA
# 3            4  KALBAR   LAKI - LAKI  40.0           23.0                  S2
# 4            5  KALBAR   LAKI - LAKI  28.0            9.0                 SMA
# ...        ...     ...           ...   ...            ...                 ...
# 289796  289797  KALSEL   LAKI - LAKI  23.0            4.0                 SMA
# 289797  289798  JATENG     PEREMPUAN  54.0           27.0                 SMA
# 289798  289799  SUMSEL   LAKI - LAKI  51.0           51.0                 SMA
# 289799  289800   JABAR   LAKI - LAKI  35.0           17.0                 SMA
# 289800  289801   JABAR   LAKI - LAKI  19.0            1.0                 SMA
#
# ...

# %%
df.to_csv ("datmin.csv",
                  index = None,
                  header=True)

# read csv file and convert
# into a dataframe object
df = pd.DataFrame(pd.read_csv("datmin.csv"))

# show the dataframe
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-79404a45b261> in <cell line: 1>()
# ----> 1 df.to_csv ("datmin.csv",
#       2                   index = None,
#       3                   header=True)
#       4
#       5 # read csv file and convert
#
# NameError: name 'df' is not defined
